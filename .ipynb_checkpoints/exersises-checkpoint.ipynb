# %%
import numpy as np

# %% [markdown]
# **Valid Sudoku**

# %%
s = np.array([
    [5, 3, 4, 6, 7, 8, 9, 1, 2],
    [6, 7, 2, 1, 9, 5, 3, 4, 8],
    [1, 9, 8, 3, 4, 2, 5, 6, 7],
    
    [8, 5, 9, 7, 6, 1, 4, 2, 3],
    [4, 2, 6, 8, 5, 3, 7, 9, 1],
    [7, 1, 3, 9, 2, 4, 8, 5, 6],
    [9, 6, 1, 5, 3, 7, 2, 8, 4],
    [2, 8, 7, 4, 1, 9, 6, 3, 5],
    [3, 4, 5, 2, 8, 6, 1, 7, 9]
])

# %%
# getting total/sum of each rows and cdataframe_columns

row_sum = np.sum(s,axis=1)
col_sum = np.sum(s,axis=0)

print(row_sum)
print(col_sum)
# Out:
# [45 45 45 45 45 45 45 45 45]
# [45 45 45 45 45 45 45 45 45]

# %%
col_sum == 45
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True])

# %% [raw]
# row_sum == 45

# %%
s
# Out:
# array([[5, 3, 4, 6, 7, 8, 9, 1, 2],
#        [6, 7, 2, 1, 9, 5, 3, 4, 8],
#        [1, 9, 8, 3, 4, 2, 5, 6, 7],
#        [8, 5, 9, 7, 6, 1, 4, 2, 3],
#        [4, 2, 6, 8, 5, 3, 7, 9, 1],
#        [7, 1, 3, 9, 2, 4, 8, 5, 6],
#        [9, 6, 1, 5, 3, 7, 2, 8, 4],
#        [2, 8, 7, 4, 1, 9, 6, 3, 5],
#        [3, 4, 5, 2, 8, 6, 1, 7, 9]])

# %%
s[0:3,0:3].sum()
# Out:
# np.int64(45)

# %%
for i in range(0,9,3):
    for j in range(0,9,3):
        n = s[i:i+3,j:j+3]
        print(n.sum())
# Out:
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45

# %% [markdown]
# **General Questions**

# %%
# Columns: [Age, Math Marks, Science Marks]
data = np.array([
    [18, 85, 78],   # Student 1
    [19, 92, 88],   # Student 2
    [17, 76, 95],   # Student 3
    [18, 65, 70],   # Student 4
    [20, 90, 85]    # Student 5
])

# %%
#Get the shape of the matrix.
s.shape
# Out:
# (9, 9)

# %%
data.shape
# Out:
# (5, 3)

# %%
#Find the average age of students.
data
# Out:
# array([[18, 85, 78],
#        [19, 92, 88],
#        [17, 76, 95],
#        [18, 65, 70],
#        [20, 90, 85]])

# %%
age_array = data[0:,0]

# %%
age_array

avg_age = age_array.mean()
print(avg_age)
# Out:
# 18.4

# %%
#Extract Math marks of all students.
math_marks = data[0:,1]
print(math_marks)
# Out:
# [85 92 76 65 90]

# %%
#Find the highest Science mark.
science_marks = data[0:,2]
print(science_marks)
max_science_marks = max(science_marks)
print(f"Maximum Science Marks: {max_science_marks}")
# Out:
# [78 88 95 70 85]
# Maximum Science Marks: 95

# %%
#Get details of the student who scored more than 90 in Math.
math_marks = data[0:,1]

# %%
math_marks
print(math_marks)
# Out:
# [85 92 76 65 90]

# %% [raw]
# more_than_90_marks = math_marks > 90
# print(data[more_than_90_marks])

# %%
#Increase Math marks of all students by 5.
print("hello world")
# Out:
# hello world

# %%
#Find how many students are younger than 19.
data
# Out:
# array([[18, 85, 78],
#        [19, 92, 88],
#        [17, 76, 95],
#        [18, 65, 70],
#        [20, 90, 85]])

# %%
younger_students = data[0:,0] < 19

# %%
younger_students
# Out:
# array([ True, False,  True,  True, False])

# %%
data[data[0:,0] < 19]
# Out:
# array([[18, 85, 78],
#        [17, 76, 95],
#        [18, 65, 70]])

# %%
#Calculate the average marks in each subject (column-wise mean).
avg_science_marks = data[0:,2].mean()
avg_math_marks = data[0:,1].mean()

print(avg_science_marks)
print(avg_math_marks)
# Out:
# 83.2
# 81.6

# %%
#Get data of students who scored at least 80 in both subjects.
data
# Out:
# array([[18, 85, 78],
#        [19, 92, 88],
#        [17, 76, 95],
#        [18, 65, 70],
#        [20, 90, 85]])

# %%
(data[data[:,1] >= 80]) & (data[data[:,2] >= 80])
# Out:
# array([[18, 84, 72],
#        [17, 76, 88],
#        [20, 90, 85]])

# %%
#Replace all Science marks < 75 with 0.

data
# Out:
# array([[18, 85, 78],
#        [19, 92, 88],
#        [17, 76, 95],
#        [18, 65, 70],
#        [20, 90, 85]])

# %%
science_marks
# Out:
# array([78, 88, 95, 70, 85])

# %%
data[data[:,2] < 75] = 0

# %%
data
# Out:
# array([[18, 85, 78],
#        [19, 92, 88],
#        [17, 76, 95],
#        [ 0,  0,  0],
#        [20, 90, 85]])
