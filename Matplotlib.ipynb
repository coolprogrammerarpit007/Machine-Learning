# %%
# Basics of Matplotlib

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,5,11)
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y = x ** 2
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y)
plt.title("Number Growth")
plt.xlabel("X - AXIS")
plt.ylabel("Y - AXIS")
# Out:
# Text(0, 0.5, 'Y - AXIS')

# %%
# subplots in matplotlib -> it means making multiple plots together

plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.plot(x,y)
plt.subplot(2,2,4)
plt.plot(y,x)

# %%
# Object Orieted Way

# firtly create an object

fig = plt.figure()  # this is a canvas obbject
axis1 = fig.add_axes([0,0,1,1])
axis2 = fig.add_axes([0.5,0.3,0.3,0.3])

axis1.plot(x,y)
axis2.plot(x,y)

# %%
# Types of Plots

plt.scatter(x,y)

# %%
from random import sample

data = sample(range(1,1000),100)
plt.hist(data)
# Out:
# (array([ 6., 14., 10.,  8., 11.,  9., 15., 10.,  9.,  8.]),
#  array([  5. , 103.7, 202.4, 301.1, 399.8, 498.5, 597.2, 695.9, 794.6,
#         893.3, 992. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x
           )
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1bf8c059810>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1bf8c059a90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1bf8c0596d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1bf8c059d10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1bf8c059e50>],
#  'means': []}

# %%
# saving plots

fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.8,0.8])
ax.plot(x,y)
plt.savefig("Basic Plot.png")

# %%
# Working with Images

import matplotlib.image as mpimg

# %%
img = mpimg.imread('hrithik.jpeg')

# %%
img
# Out:
# array([[[ 91,  91,  93],
#         [ 91,  91,  93],
#         [ 91,  91,  93],
#         ...,
#         [122, 122, 122],
#         [122, 122, 122],
#         [122, 122, 122]],
#
#        [[ 91,  91,  93],
#         [ 91,  91,  93],
#         [ 91,  91,  93],
#         ...,
#         [122, 122, 122],
#         [122, 122, 122],
#         [122, 122, 122]],
#
#        [[ 91,  91,  93],
#         [ 91,  91,  93],
#         [ 91,  91,  93],
#         ...,
#         [122, 122, 122],
#         [122, 122, 122],
#         [122, 122, 122]],
#
#        ...,
#
#        [[245, 253, 255],
#         [245, 253, 255],
#         [245, 253, 255],
#         ...,
#         [153, 153, 153],
#         [153, 153, 153],
#         [153, 153, 153]],
#
#        [[245, 253, 255],
#         [245, 253, 255],
#         [245, 253, 255],
#         ...,
#         [153, 153, 153],
#         [153, 153, 153],
#         [153, 153, 153]],
#
#        [[245, 253, 255],
#         [245, 253, 255],
#         [245, 253, 255],
# ...

# %%
plt.imshow(img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(451.5), np.float64(677.5), np.float64(-0.5))

# %%
cropped_img = img[50:200,100:300]  # crop rows 50-100 and cols 100-300

plt.imshow(cropped_img)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(199.5), np.float64(149.5), np.float64(-0.5))

# %%
# Distribution Plots

# %%
# Quantitative Variable -> Values are continous mainly in numerical
# Categorical Variable -> divided in categorical

# %%
# # Distribution plots are created for quantitative variable...
# We use distribution plots to visualize the distribution of quantitative data.

# Let's discuss some plots that allow us to visualize the distribution of a data set. These plots are:

# distplot/histplot
# jointplot
# pairplot
# rugplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5])

# %%
sns.histplot(df["total_bill"],bins=20)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
# When working with Seaborn histograms (sns.histplot), bins determine how your numerical data is grouped into intervals. Understanding bins is important because they directly affect how your data distribution appears.

# %%
# What are Bins?

# A bin is simply an interval (or bucket) that groups values together.

# Suppose you have exam scores:

# %%
scores = [42, 45, 47, 49, 52, 55, 57, 61, 65, 68, 72, 75, 78, 82, 88]

# %%
sns.histplot(scores,bins=5)
# Out:
# <Axes: ylabel='Count'>

# %%
# # Kernel Density Estimator (KDE)
# What is a Kernel Density Estimator (KDE)?

# A Kernel Density Estimator (KDE) is a technique used to estimate the probability density of a continuous variable.

# In simple words:

# A KDE creates a smooth curve that shows how your data is distributed, instead of grouping it into bars like a histogram.
# # KDE is one of the most useful concepts in data visualization and statistics. Let's understand it from the basics.

# %%
marks = [55, 57, 60, 62, 63, 65, 67, 70, 72, 75]

# %%
plt.subplot(1,2,1)
sns.histplot(df["total_bill"],bins=20,kde=True)
plt.subplot(1,2,2)
sns.histplot(df["tip"],bins=20,kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
# Join Plot:- for compariring two quantitive variables

# %%
sns.jointplot(x='total_bill',y='tip',data=df)

# %%
# Pair Plot

# %%
sns.pairplot(df,hue="size",palette='rainbow')

# %%
# rugplot

sns.rugplot(df['total_bill'])
# Out:
# <Axes: xlabel='total_bill'>

# %%
# Categorical Plots
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Count Plots

sns.countplot(x=df["sex"],hue=df["smoker"])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
# barplots

sns.barplot(x=df["sex"],y=df["total_bill"],estimator=np.sum)#default estimator set to mean
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
# bosplots

sns.boxplot(x='tip',y='day',data=df,palette="rainbow")
# Out:
# C:\Users\Hello\AppData\Local\Temp\ipykernel_18312\288687940.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='tip',y='day',data=df,palette="rainbow")
# <Axes: xlabel='tip', ylabel='day'>

# %% [markdown]
# ## boxplot and violinplot
#
# boxplots and violinplots are used to shown the distribution of categorical data. A box plot (or box-and-whisker plot) shows the distribution of quantitative data in a way that facilitates comparisons between variables or across levels of a categorical variable. The box shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution, except for points that are determined to be “outliers” using a method that is a function of the inter-quartile range.

# %%
sns.violinplot(x=df["day"],y=df["total_bill"])
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# stripplot and swarmplot
# The stripplot will draw a scatterplot where one variable is categorical. A strip plot can be drawn on its own, but it is also a good complement to a box or violin plot in cases where you want to show all observations along with some representation of the underlying distribution.
#
# The swarmplot is similar to stripplot(), but the points are adjusted (only along the categorical axis) so that they don’t overlap. This gives a better representation of the distribution of values, although it does not scale as well to large numbers of observations (both in terms of the ability to show all the points and in terms of the computation needed to arrange them).

# %%
sns.stripplot(x='day',y="total_bill",data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day',y="total_bill",data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='tip',y="day",data=df)
sns.swarmplot(x='tip',y="day",data=df)
# Out:
# D:\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 9.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 10.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='tip', ylabel='day'>
# D:\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 8.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
